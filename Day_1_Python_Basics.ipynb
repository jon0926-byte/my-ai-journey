# %% [markdown]
# <a href="https://colab.research.google.com/github/jon0926-byte/my-ai-journey/blob/main/Day_1_Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World! I am starting my AI Engineering journey today.")
# Out:
# Hello World! I am starting my AI Engineering journey today.
